# %%
# !pip install -U PyYAML
from IPython.display import clear_output
clear_output()

#check gpu model
from tensorflow.python.client import device_lib
device_lib.list_local_devices()[3]
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5414757206063369441
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"

# %% [markdown]
# # Copy Github Code

# %%
# !rm -r sample_data

# !git clone https://github.com/ultralytics/yolov5.git

# !cd yolov5/
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 3123 (delta 6), reused 7 (delta 4), pack-reused 3109
# Receiving objects: 100% (3123/3123), 6.45 MiB | 23.67 MiB/s, done.
# Resolving deltas: 100% (2074/2074), done.

# %% [markdown]
# # Get the Data

# %%
# %cd /content/yolov5/data/
# !gdown --id '1je_X6NIEHVpT90d7vIfYpfKjK0ZaU7d5'

# !unzip dhaka-traffic-yolo-v3_seed_401.zip
# !rm dhaka-traffic-yolo-v3_seed_401.zip
# %mv './metadata/train.txt' './metadata/valid.txt' './metadata/test.txt' './metadata/traffic.data' './metadata/traffic.names' .
clear_output()
print('Now take care of the .yaml file')
# Out:
# Now take care of the .yaml file

# %%
# # Start tensorboard (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs
# %reload_ext tensorboard

# %%
# %cd /content/yolov5
# !python train.py --img 640 --batch 16 --epochs 350 --data data/traffic.yaml --cfg yolov5l.yaml --weights yolov5l.pt --resume
# Out:
# /content/yolov5
# Resuming training from ./runs/exp0/weights/last.pt
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='', data='data/traffic.yaml', device='', epochs=350, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=True, single_cls=False, sync_bn=False, total_batch_size=16, weights='./runs/exp0/weights/last.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# 2020-10-16 15:33:03.597252: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !zip -r model_l_63.zip yolov5
# !mv model_l_63.zip '/content/drive/My Drive/Dhaka-ai/YOLOv5'
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: yolov5/data/train/Navid_53.jpg (deflated 0%)
#   adding: yolov5/data/train/Navid_164.xml (deflated 71%)
#   adding: yolov5/data/train/Pias (202).txt (deflated 54%)
#   adding: yolov5/data/train/Pias (494).jpg (deflated 1%)
#   adding: yolov5/data/train/Dipto_ 73.jpg (deflated 3%)
#   adding: yolov5/data/train/Dipto_563.xml (deflated 49%)
#   adding: yolov5/data/train/Navid_713.xml (deflated 71%)
#   adding: yolov5/data/train/Navid_166.jpg (deflated 1%)
#   adding: yolov5/data/train/Navid_246.xml (deflated 67%)
#   adding: yolov5/data/train/113.txt (deflated 58%)
#   adding: yolov5/data/train/Navid_98.txt (deflated 44%)
#   adding: yolov5/data/train/Navid_653.xml (deflated 80%)
#   adding: yolov5/data/train/Navid_184.xml (deflated 60%)
#   adding: yolov5/data/train/Navid_207.xml (deflated 67%)
#   adding: yolov5/data/train/Pias (120).jpg (deflated 0%)
#   adding: yolov5/data/train/Numan_(361).xml (deflated 79%)
# ...
